# %% [markdown]
# 🧠 **Storytelling**
#
# 1. Quais produtos vendem mais em volume?
# 2. Quais geram mais dinheiro em faturamento líquido?
#
# Esses dados serão usados para promoções, foco em estoque e campanhas de remarketing.

# %% [markdown]
# ✅ **Pré-requisitos**
#
# Antes de rodar o script, instale as bibliotecas necessárias:

# %%
pip install pandas matplotlib openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 📜 **Código**

# %%
# Importações necessárias
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 1. Carregar os dados do Excel
arquivo = '/kaggle/input/dataset/dados.xlsx'
df = pd.read_excel(arquivo)

# %%
# 2. Agrupar por produto: soma de quantidade vendida e total líquido
ranking_produtos = df.groupby('produto').agg({
    'quantidade': 'sum',
    'valor total liquido': 'sum'
}).reset_index()

# %%
# 3. Top 10 Produtos por Volume de Vendas
top_vendas = ranking_produtos.sort_values(by='quantidade', ascending=False).head(10)

# %%
# 4. Top 10 Produtos por Faturamento Líquido
top_faturamento = ranking_produtos.sort_values(by='valor total liquido', ascending=False).head(10)

# %%
# 5. Visualização com Matplotlib
plt.figure(figsize=(14, 6))

# %%
# Gráfico 1: Mais Vendidos
plt.subplot(1, 2, 1)
plt.barh(top_vendas['produto'], top_vendas['quantidade'], color='dodgerblue')
plt.title('🏆 Top 10 Produtos Mais Vendidos')
plt.xlabel('Quantidade Vendida')
plt.gca().invert_yaxis()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 127942 (\N{TROPHY}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127942 (\N{TROPHY}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Gráfico 2: Mais Lucrativos
plt.subplot(1, 2, 2)
plt.barh(top_faturamento['produto'], top_faturamento['valor total liquido'], color='seagreen')
plt.title('💰 Top 10 Produtos Mais Lucrativos')
plt.xlabel('Faturamento Líquido (R$)')
plt.gca().invert_yaxis()

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_35/2162903208.py:8: UserWarning: Glyph 128176 (\N{MONEY BAG}) missing from current font.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128176 (\N{MONEY BAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 6. Mostrar dados em tabelas
print("🏆 Top 10 Produtos Mais Vendidos (por Quantidade):\n")
print(top_vendas)
print("\n💰 Top 10 Produtos Mais Lucrativos (por Faturamento Líquido):\n")
print(top_faturamento)
# Out:
# 🏆 Top 10 Produtos Mais Vendidos (por Quantidade):
#
#                  produto  quantidade  valor total liquido
# 23     Hidroclorotiazida     1082068          21702370.80
# 13               Codeína     1080773           4854811.68
# 9             Cetirizina     1078031          53570102.00
# 14          Dexametasona     1077478          45088775.76
# 4              Apixabana     1076206          45407969.00
# 10            Citalopram     1075161           2143240.44
# 1   Alendronato de Sódio     1075141           3744502.51
# 2             Alprazolam     1072729          29698752.05
# 36            Nimesulida     1072602          16523827.39
# 21            Fluoxetina     1070823          22417971.66
#
# 💰 Top 10 Produtos Mais Lucrativos (por Faturamento Líquido):
#
#                              produto  quantidade  valor total liquido
# 9                         Cetirizina     1078031          53570102.00
# 16                       Domperidona     1045939          52057387.80
# ...
